# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel('../data/sales_clean.xlsx')

# %%
df.head(10)
# Out:
#       order_id  total_qty  total_weight_gr  total_returned_qty  \
# 0  ORD_0000001          2             2000                   0
# 1  ORD_0000002          1              500                   0
# 2  ORD_0000003          1              500                   0
# 3  ORD_0000004          2              400                   0
# 4  ORD_0000005          3             3600                   0
# 5  ORD_0000006          2             1000                   0
# 6  ORD_0000007          1             1700                   0
# 7  ORD_0000008          1              500                   0
# 8  ORD_0000009          1              500                   0
# 9  ORD_0000010          6            12900                   0
#
#    total_discount                    product_categories  \
# 0               0                              Celengan
# 1               0                              Celengan
# 2               0                              Celengan
# 3               0                 Mangkok Sambal / Saus
# 4               0         Keranjang, Other, Tempat Nasi
# 5               0                              Celengan
# 6               0                         Nampan / Tray
# 7               0                              Celengan
# 8               0                              Celengan
# 9               0  Aksesoris Mandi, Celengan, Keranjang
#
#    num_product_categories order_status  \
# 0                       1      Selesai
# 1                       1      Selesai
# 2                       1      Selesai
# 3                       1      Selesai
# 4                       3        Batal
# 5                       1      Selesai
# 6                       1        Batal
# 7                       1      Selesai
# 8                       1        Batal
# 9                       3      Selesai
#
#                                         cancellation  \
# 0                                      Not Cancelled
# 1                                      Not Cancelled
# 2                                      Not Cancelled
# 3                                      Not Cancelled
# 4  Dibatalkan oleh Pembeli. Alasan: Ubah Pesanan ...
# 5                                      Not Cancelled
# 6  Dibatalkan oleh Pembeli. Alasan: Ubah Pesanan ...
# 7                                      Not Cancelled
# 8  Dibatalkan oleh Pembeli. Alasan: Ubah Pesanan ...
# 9                                      Not Cancelled
#
#                    shipping_option  ... estimated_shipping_cost_discount  \
# 0  Reguler (Cashless)-SPX Standard  ...                            10000
# 1            Hemat Kargo-SPX Hemat  ...                            14500
# 2            Hemat Kargo-SPX Hemat  ...                             8000
# 3            Hemat Kargo-SPX Hemat  ...                            20000
# 4            Hemat Kargo-SPX Hemat  ...                                0
# 5            Hemat Kargo-SPX Hemat  ...                            10000
# 6            Hemat Kargo-SPX Hemat  ...                                0
# 7            Hemat Kargo-SPX Hemat  ...                             8000
# 8          Hemat Kargo-J&T Economy  ...                                0
# 9            Hemat Kargo-SPX Hemat  ...                            20000
#
#   total_payment estimated_shipping_cost          order_time  \
# 0         38300                   10000 2024-04-01 00:15:00
# 1         18576                   14500 2024-04-01 01:47:00
# 2          7069                    8000 2024-04-01 04:25:00
# 3         32200                   20000 2024-04-01 04:41:00
# 4             0                    8000 2024-04-01 06:12:00
# 5         40996                   10000 2024-04-01 07:09:00
# 6             0                   16000 2024-04-01 07:23:00
# 7         18280                    8000 2024-04-01 07:33:00
# 8             0                   16500 2024-04-01 07:56:00
# 9         92800                   33000 2024-04-01 08:27:00
#
#            source_file  month_period  day_of_week profit order_segment  \
# 0  AprilSales2024.xlsx       2024-04       Monday  38300         Small
# 1  AprilSales2024.xlsx       2024-04       Monday  18576        Single
# 2  AprilSales2024.xlsx       2024-04       Monday   7069        Single
# 3  AprilSales2024.xlsx       2024-04       Monday  32200         Small
# 4  AprilSales2024.xlsx       2024-04       Monday      0         Small
# 5  AprilSales2024.xlsx       2024-04       Monday  40996         Small
# 6  AprilSales2024.xlsx       2024-04       Monday      0        Single
# 7  AprilSales2024.xlsx       2024-04       Monday  18280        Single
# 8  AprilSales2024.xlsx       2024-04       Monday      0        Single
# 9  AprilSales2024.xlsx       2024-04       Monday  79800        Medium
#
#    discount_segment
# 0  WithOut Discount
# 1  WithOut Discount
# 2  WithOut Discount
# 3  WithOut Discount
# 4  WithOut Discount
# 5  WithOut Discount
# 6  WithOut Discount
# 7  WithOut Discount
# 8  WithOut Discount
# 9  WithOut Discount
#
# [10 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20848 entries, 0 to 20847
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   order_id                          20848 non-null  object
#  1   total_qty                         20848 non-null  int64
#  2   total_weight_gr                   20848 non-null  int64
#  3   total_returned_qty                20848 non-null  int64
#  4   total_discount                    20848 non-null  int64
#  5   product_categories                20848 non-null  object
#  6   num_product_categories            20848 non-null  int64
#  7   order_status                      20848 non-null  object
#  8   cancellation                      20848 non-null  object
#  9   shipping_option                   20848 non-null  object
#  10  payment_method                    20848 non-null  object
#  11  city                              20848 non-null  object
#  12  province                          20848 non-null  object
#  13  shipping_cost                     20848 non-null  int64
#  14  estimated_shipping_cost_discount  20848 non-null  int64
#  15  total_payment                     20848 non-null  int64
#  16  estimated_shipping_cost           20848 non-null  int64
#  17  order_time                        20848 non-null  datetime64[ns]
#  18  source_file                       20848 non-null  object
#  19  month_period                      20848 non-null  object
#  20  day_of_week                       20848 non-null  object
#  21  profit                            20848 non-null  int64
#  22  order_segment                     20848 non-null  object
#  23  discount_segment                  20848 non-null  object
# dtypes: datetime64[ns](1), int64(10), object(13)
# memory usage: 3.8+ MB

# %%
for col in ['order_status', 'shipping_option', 'payment_method', 'city', 'province', 'source_file', 'month_period', 'day_of_week', 'order_segment', 'discount_segment']:
    print(f"Kolom {col} memiliki kata unique {df[col].nunique()}")
    print(f"Datanya: {df[col].unique()}")
    print("="*50)
# Out:
# Kolom order_status memiliki kata unique 2
# Datanya: ['Selesai' 'Batal']
# ==================================================
# Kolom shipping_option memiliki kata unique 45
# Datanya: ['Reguler (Cashless)-SPX Standard' 'Hemat Kargo-SPX Hemat'
#  'Hemat Kargo-J&T Economy' 'Instant (Versi Lama)-SPX Instant (Versi Lama)'
#  'Agen SPX Express'
#  'Instant (Versi Lama)-GrabExpress Instant (Versi Lama)'
#  'Reguler (Cashless)-J&T Express' 'Same Day-SPX Sameday'
#  'Reguler (Cashless)-JNE Reguler' 'Hemat Kargo' 'Kargo-JNE Trucking (JTR)'
#  'Kargo-J&T Cargo' 'Next Day-JNE YES' 'Instant (Versi Lama)'
#  'Same Day-GoSend Same Day' 'SPX Express Point'
#  'Instant (Versi Lama)-GoSend Instant (Versi Lama)' 'Reguler (Cashless)'
#  'GrabExpress Instant (Versi Lama)' 'SPX Hemat' 'SPX Standard' 'J&T Cargo'
#  'J&T Express' 'GrabExpress Sameday' 'JNE Reguler' 'GoSend Same Day'
#  'SPX Sameday' 'Kargo' 'Same Day' 'Next Day'
#  'Hemat Kargo-JNE Trucking (JTR)' 'Hemat Kargo-J&T Cargo'
#  'GoSend Instant (Versi Lama)' 'SPX Instant (Versi Lama)' 'J&T Economy'
#  'JNE Trucking (JTR)' 'JNE YES' 'Instant-SPX Instant'
#  'GrabExpress Instant' 'Instant' 'Instant Prioritas-SPX Instant Prioritas'
#  'SPX Instant' 'GoSend Instant Prioritas' 'SPX Instant Prioritas'
#  'Gosend Instant']
# ==================================================
# Kolom payment_method memiliki kata unique 12
# Datanya: ['Saldo ShopeePay' 'COD (Bayar di Tempat)' 'SeaBank Bayar Instan'
#  'SPayLater' 'Online Payment' 'Kartu Kredit/Debit' 'Indomaret/i.Saku'
#  'Alfamart/Alfamidi/Dan+Dan' 'Cicilan Kartu Kredit' 'BCA OneKlik'
#  'Pembayaran dibebaskan' 'Mitra Shopee']
# ==================================================
# Kolom city memiliki kata unique 424
# Datanya: ['KOTA SERANG' 'KOTA SEMARANG' 'KAB. BOGOR' 'KOTA JAMBI' 'KOTA TANGERANG'
#  'KAB. BANDUNG' 'KAB. GARUT' 'KAB. TEGAL' 'KAB. SIAK' 'KAB. SUKABUMI'
#  'KAB. PANDEGLANG' 'KOTA BEKASI' 'KAB. KARANGANYAR' 'KAB. BEKASI'
#  'KOTA DEPOK' 'KAB. LAMPUNG UTARA' 'KAB. TANGERANG' 'KAB. SUBANG'
#  'KAB. BONE' 'KOTA BENGKULU' 'KOTA JAKARTA TIMUR' 'KAB. LAMPUNG TIMUR'
#  'KAB. KEBUMEN' 'KOTA JAKARTA BARAT' 'KAB. LUMAJANG' 'KAB. KARAWANG'
#  'KAB. KEPULAUAN SIAU TAGULANDANG BIARO (SITARO)' 'KOTA JAKARTA SELATAN'
#  'KOTA SUKABUMI' 'KAB. SIDENRENG RAPPANG/RAPANG' 'KAB. GRESIK'
#  'KOTA TANGERANG SELATAN' 'KAB. LAMPUNG TENGAH' 'KOTA JAKARTA UTARA'
#  'KAB. KOTA WARINGIN BARAT' 'KAB. BANDUNG BARAT' 'KOTA BOGOR'
#  'KOTA SALATIGA' 'KAB. KUTAI BARAT' 'KAB. BREBES' 'KAB. BANJARNEGARA'
#  'KOTA SURABAYA' 'KAB. LEBAK' 'KOTA MAKASSAR' 'KAB. DELI SERDANG'
#  'KAB. LAMONGAN' 'KOTA CIMAHI' 'KAB. KAUR' 'KAB. SEMARANG' 'KAB. TEBO'
#  'KAB. MERANGIN' 'KAB. PASAMAN' 'KOTA MALANG' 'KAB. PEMALANG'
#  'KOTA BANDUNG' 'KOTA JAKARTA PUSAT' 'KOTA PADANG' 'KAB. KUNINGAN'
#  'KAB. BANGKALAN' 'KAB. KOTA WARINGIN TIMUR' 'KAB. TUBAN' 'KAB. SUMEDANG'
#  'KAB. CIAMIS' 'KAB. LUWU' 'KOTA CILEGON' 'KOTA PANGKAL PINANG'
#  'KOTA PALEMBANG' 'KOTA BANDAR LAMPUNG' 'KOTA SINGKAWANG' 'KAB. KATINGAN'
#  'KAB. LAHAT' 'KOTA BATAM' 'KAB. MALANG' 'KAB. ACEH BARAT'
#  'KAB. TULUNGAGUNG' 'KAB. SLEMAN' 'KOTA TASIKMALAYA' 'KAB. SERANG'
#  'KAB. HULU SUNGAI UTARA' 'KAB. SIDOARJO' 'KAB. SAMPANG' 'KAB. CIANJUR'
#  'KAB. TANJUNG JABUNG BARAT' 'KOTA CIREBON' 'KAB. LAMPUNG SELATAN'
#  'KAB. PARIGI MOUTONG' 'KOTA MEDAN' 'KAB. SITUBONDO' 'KOTA PEKANBARU'
#  'KAB. NGAWI' 'KAB. BUNGO' 'KAB. BARITO UTARA' 'KAB. PELALAWAN'
#  'KAB. INDRAMAYU' 'KAB. MUSI RAWAS UTARA' 'KAB. PESISIR BARAT'
#  'KAB. PADANG PARIAMAN' 'KOTA PONTIANAK' 'KAB. SINTANG' 'KOTA BANJARMASIN'
#  'KAB. KAMPAR' 'KAB. OGAN ILIR' 'KAB. KUTAI KARTANEGARA' 'KOTA BALIKPAPAN'
#  'KOTA TERNATE' 'KAB. TANAH BUMBU' 'KAB. BLORA' 'KOTA BUKITTINGGI'
#  'KAB. GIANYAR' 'KAB. PONOROGO' 'KOTA PARIAMAN' 'KAB. TULANG BAWANG'
#  'KAB. CIREBON' 'KAB. PURWAKARTA' 'KAB. BANGKA SELATAN' 'KAB. WAJO'
#  'KAB. BANJAR' 'KAB. PASAMAN BARAT' 'KAB. PAMEKASAN' 'KAB. SERUYAN'
#  'KAB. KERINCI' 'KAB. BATANG HARI' 'KAB. BANGKA' 'KAB. GROBOGAN'
#  'KOTA YOGYAKARTA' 'KOTA SURAKARTA (SOLO)' 'KAB. JEMBRANA' 'KAB. BANTUL'
#  'KAB. PEKALONGAN' 'KAB. KUDUS' 'KOTA GUNUNGSITOLI' 'KAB. PASURUAN'
#  'KOTA PEKALONGAN' 'KAB. MINAHASA SELATAN' 'KAB. MAJALENGKA'
#  'KAB. MOROWALI' 'KAB. KEPULAUAN MENTAWAI' 'KAB. KUBU RAYA' 'KAB. TAPIN'
#  'KAB. PACITAN' 'KAB. SUMENEP' 'KAB. BLITAR' 'KAB. WONOSOBO'
#  'KAB. OGAN KOMERING ULU TIMUR' 'KAB. KENDAL' 'KOTA DENPASAR'
#  'KAB. ROKAN HILIR' 'KAB. CILACAP' 'KAB. TANJUNG JABUNG TIMUR'
#  'KAB. PROBOLINGGO' 'KAB. PATI' 'KAB. BENGKULU UTARA'
#  'KAB. OGAN KOMERING ILIR' 'KAB. BANGKA TENGAH' 'KAB. JEPARA'
#  'KAB. KEDIRI' 'KAB. SANGGAU' 'KAB. MADIUN' 'KAB. REJANG LEBONG'
#  'KAB. MAGELANG' 'KAB. BENGKULU SELATAN' 'KAB. BOJONEGORO'
#  'KAB. MANDAILING NATAL' 'KAB. LOMBOK TENGAH' 'KAB. DEMAK'
#  'KAB. BONE BOLANGO' 'KAB. SUKOHARJO' 'KAB. LUWU TIMUR' 'KAB. MAROS'
#  'KAB. BANYUASIN' 'KOTA MATARAM' 'KAB. LEBONG' 'KAB. TANAH LAUT'
#  'KOTA PRABUMULIH' 'KAB. MUSI RAWAS' 'KOTA KEDIRI'
#  'KAB. OGAN KOMERING ULU SELATAN' 'KAB. BONDOWOSO' 'KAB. BADUNG'
#  'KAB. PURWOREJO' 'KAB. PRINGSEWU' 'KAB. MUSI BANYUASIN' 'KAB. SRAGEN'
#  'KAB. GORONTALO' 'KAB. SUMBA TIMUR' 'KAB. MINAHASA UTARA'
#  'KOTA GORONTALO' 'KOTA BANDA ACEH' 'KAB. POSO' 'KAB. BIREUEN'
#  'KAB. PASER' 'KAB. BENGKALIS' 'KOTA BANJARBARU' 'KOTA TEGAL'
#  'KAB. PINRANG' 'KAB. TASIKMALAYA' 'KAB. PIDIE JAYA' 'KAB. PULANG PISAU'
#  'KAB. BANYUMAS' 'KOTA BANJAR' 'KAB. DOMPU' 'KAB. KLATEN'
#  'KAB. OGAN KOMERING ULU' 'KAB. BULUKUMBA' 'KAB. BELITUNG'
#  'KAB. TEMANGGUNG' 'KAB. TANGGAMUS' 'KAB. BOYOLALI' 'KAB. MAMUJU'
#  'KAB. INDRAGIRI HILIR' 'KAB. JOMBANG' 'KAB. INDRAGIRI HULU' 'KAB. SAMBAS'
#  'KAB. LABUHAN BATU' 'KOTA LUBUK LINGGAU' 'KAB. MUARO JAMBI'
#  'KOTA PALANGKA RAYA' 'KAB. SUMBAWA BARAT' 'KOTA MANADO' 'KAB. BATANG'
#  'KAB. HALMAHERA UTARA' 'KAB. KEPULAUAN TALAUD' 'KAB. BANTAENG'
#  'KAB. NGANJUK' 'KOTA MADIUN' 'KOTA SAMARINDA' 'KOTA DUMAI'
#  'KAB. LABUHAN BATU SELATAN' 'KAB. ACEH SELATAN' 'KAB. WAY KANAN'
#  'KAB. GUNUNG KIDUL' 'KAB. BANYUWANGI' 'KAB. MUARA ENIM' 'KAB. MAGETAN'
#  'KAB. KOLAKA UTARA' 'KAB. BANGKA BARAT' 'KAB. MOJOKERTO' 'KAB. BANGLI'
#  'KAB. PENUKAL ABAB LEMATANG ILIR' 'KAB. TANAH DATAR' 'KOTA BINJAI'
#  'KOTA TANJUNG PINANG' 'KAB. LIMA PULUH KOTO/KOTA' 'KAB. NIAS SELATAN'
#  'KOTA BATU' 'KAB. JEMBER' 'KAB. KUANTAN SINGINGI' 'KAB. LOMBOK TIMUR'
#  'KAB. SIMALUNGUN' 'KAB. SELUMA' 'KAB. BANGGAI' 'KAB. GUNUNG MAS'
#  'KAB. LOMBOK BARAT' 'KAB. NAGAN RAYA' 'KAB. BULELENG' 'KAB. KUTAI TIMUR'
#  'KAB. KARANGASEM' 'KOTA AMBON' 'KAB. LAMPUNG BARAT' 'KAB. KLUNGKUNG'
#  'KAB. PONTIANAK' 'KAB. TAKALAR' 'KAB. KETAPANG' 'KAB. SEKADAU'
#  'KAB. SUKAMARA' 'KAB. DHARMASRAYA' 'KAB. ACEH UTARA' 'KAB. REMBANG'
#  'KAB. KONAWE UTARA' 'KOTA BONTANG' 'KAB. WONOGIRI' 'KOTA PALU'
#  'KAB. KEPULAUAN ANAMBAS' 'KAB. HALMAHERA TIMUR' 'KAB. ROKAN HULU'
#  'KAB. KULON PROGO' 'KAB. BENGKAYANG' 'KAB. ENREKANG'
#  'KAB. TULANG BAWANG BARAT' 'KAB. GOWA' 'KAB. TABALONG'
#  'KAB. LOMBOK UTARA' 'KAB. ROTE NDAO' 'KAB. KAPUAS HULU'
#  'KAB. ACEH TENGAH' 'KAB. KOTA BARU' 'KAB. SAROLANGUN' 'KAB. PANGANDARAN'
#  'KAB. DAIRI' 'KAB. SIJUNJUNG (SAWAH LUNTO SIJUNJUNG)' 'KAB. LANGKAT'
#  'KAB. PURBALINGGA' 'KAB. SIMEULUE' 'KOTA TARAKAN' 'KAB. TAPANULI UTARA'
#  'KAB. SERDANG BEDAGAI' 'KAB. SOLOK SELATAN' 'KOTA BLITAR'
#  'KOTA PROBOLINGGO' 'KAB. HUMBANG HASUNDUTAN' 'KAB. PESISIR SELATAN'
#  'KAB. NATUNA' 'KOTA MAGELANG' 'KAB. TRENGGALEK' 'KAB. BERAU'
#  'KAB. MUKO MUKO' 'KAB. BOLAANG MONGONDOW SELATAN' 'KOTA PALOPO'
#  'KAB. MURUNG RAYA' 'KAB. BUOL' 'KAB. SUMBAWA' 'KAB. PESAWARAN'
#  'KOTA PEMATANG SIANTAR' 'KOTA SUNGAIPENUH' 'KOTA PAREPARE' 'KOTA SOLOK'
#  'KOTA LANGSA' 'KAB. KARIMUN' 'KAB. KAPUAS' 'KAB. ACEH TIMUR'
#  'KAB. POHUWATO' 'KAB. KEPAHIANG' 'KAB. MINAHASA TENGGARA' 'KAB. BARRU'
#  'KAB. BATU BARA' 'KAB. LANDAK' 'KAB. SIKKA' 'KAB. BOMBANA'
#  'KOTA KOTAMOBAGU' 'KAB. BARITO TIMUR' 'KAB. MESUJI' 'KAB. MAMUJU UTARA'
#  'KAB. TABANAN' 'KAB. EMPAT LAWANG' 'KAB. KARO' 'KAB. ASAHAN'
#  'KAB. TAPANULI TENGAH' 'KAB. TOBA SAMOSIR' 'KAB. NUNUKAN' 'KOTA PASURUAN'
#  'KAB. BELITUNG TIMUR' 'KOTA LHOKSEUMAWE' 'KOTA PAGAR ALAM' 'KAB. KUPANG'
#  'KAB. SUMBA BARAT' 'KAB. BARITO KUALA' 'KOTA KENDARI'
#  'KAB. LABUHAN BATU UTARA' 'KOTA METRO' 'KOTA KUPANG' 'KOTA BIMA'
#  'KAB. BIMA' 'KAB. MAHAKAM ULU' 'KOTA MOJOKERTO' 'KAB. PADANG LAWAS'
#  'KAB. BINTAN' 'KAB. HALMAHERA TENGAH' 'KAB. PANGKAJENE KEPULAUAN'
#  'KAB. KEPULAUAN MERANTI' 'KAB. ENDE' 'KAB. MOROWALI UTARA' 'KAB. SOLOK'
#  'KAB. POLEWALI MANDAR' 'KAB. MALAKA' 'KAB. TANA TORAJA'
#  'KAB. HULU SUNGAI TENGAH' 'KAB. ACEH TAMIANG' 'KOTA SAWAH LUNTO'
#  'KAB. NGADA' 'KAB. BOLAANG MONGONDOW (BOLMONG)' 'KAB. TAPANULI SELATAN'
#  'KAB. MELAWI' 'KAB. SOPPENG' 'KAB. KONAWE SELATAN' 'KAB. LINGGA'
#  'KAB. WAKATOBI' 'KAB. MANGGARAI BARAT' 'KAB. KAYONG UTARA'
#  'KAB. LUWU UTARA' 'KAB. LAMANDAU' 'KAB. BENGKULU TENGAH' 'KAB. AGAM'
#  'KAB. HULU SUNGAI SELATAN' 'KAB. BENER MERIAH' 'KOTA PAYAKUMBUH'
#  'KOTA SIBOLGA' 'KAB. JENEPONTO' 'KAB. PIDIE'
#  'KAB. BOLAANG MONGONDOW UTARA' 'KAB. NIAS UTARA'
#  'KAB. PENAJAM PASER UTARA' 'KAB. TIMOR TENGAH UTARA' 'KAB. TOJO UNA-UNA'
#  'KAB. BARITO SELATAN' 'KAB. SINJAI' 'KAB. GORONTALO UTARA'
#  'KAB. MINAHASA' 'KAB. MUNA' 'KAB. TORAJA UTARA' 'KAB. MAJENE'
#  'KAB. JAYAWIJAYA' 'KAB. BOALEMO' 'KOTA TEBING TINGGI'
#  'KAB. KEPULAUAN SERIBU' 'KAB. BALANGAN' 'KAB. KOLAKA TIMUR'
#  'KAB. BOLAANG MONGONDOW TIMUR' 'KAB. DONGGALA' 'KAB. BANGGAI LAUT'
#  'KAB. SAMOSIR' 'KAB. GAYO LUES' 'KAB. ACEH JAYA' 'KOTA SABANG'
#  'KAB. ACEH BESAR' 'KAB. MAMASA' 'KAB. PADANG LAWAS UTARA' 'KAB. KOLAKA'
#  'KAB. ACEH SINGKIL' 'KOTA PADANG SIDEMPUAN' 'KAB. ACEH BARAT DAYA'
#  'KAB. TOLI-TOLI' 'KAB. MAMUJU TENGAH' 'KAB. BULUNGAN (BULONGAN)'
#  'KOTA SORONG']
# ==================================================
# Kolom province memiliki kata unique 34
# Datanya: ['BANTEN' 'JAWA TENGAH' 'JAWA BARAT' 'JAMBI' 'RIAU' 'LAMPUNG'
#  'SULAWESI SELATAN' 'BENGKULU' 'DKI JAKARTA' 'JAWA TIMUR' 'SULAWESI UTARA'
#  'KALIMANTAN TENGAH' 'KALIMANTAN TIMUR' 'SUMATERA UTARA' 'SUMATERA BARAT'
#  'BANGKA BELITUNG' 'SUMATERA SELATAN' 'KALIMANTAN BARAT' 'KEPULAUAN RIAU'
#  'NANGGROE ACEH DARUSSALAM (NAD)' 'DI YOGYAKARTA' 'KALIMANTAN SELATAN'
#  'SULAWESI TENGAH' 'MALUKU UTARA' 'BALI' 'NUSA TENGGARA BARAT (NTB)'
#  'GORONTALO' 'NUSA TENGGARA TIMUR (NTT)' 'SULAWESI BARAT'
#  'SULAWESI TENGGARA' 'MALUKU' 'KALIMANTAN UTARA' 'PAPUA' 'PAPUA BARAT']
# ==================================================
# Kolom source_file memiliki kata unique 24
# Datanya: ['AprilSales2024.xlsx' 'AprilSales2025.xlsx' 'AugustSales2024.xlsx'
#  'AugustSales2025.xlsx' 'DecemberSales2023.xlsx' 'DecemberSales2024.xlsx'
#  'FebruarySales2024.xlsx' 'FebruarySales2025.xlsx' 'JanuarySales2024.xlsx'
#  'JanuarySales2025.xlsx' 'JulySales2024.xlsx' 'JulySales2025.xlsx'
#  'JuneSales2024.xlsx' 'JuneSales2025.xlsx' 'MarchSales2024.xlsx'
#  'MarchSales2025.xlsx' 'MaySales2024.xlsx' 'MaySales2025.xlsx'
#  'NovemberSales2024.xlsx' 'NovemberSales2025.xlsx' 'OctoberSales2024.xlsx'
#  'OctoberSales2025.xlsx' 'SeptemberSales2024.xlsx'
#  'SeptemberSales2025.xlsx']
# ==================================================
# Kolom month_period memiliki kata unique 24
# Datanya: ['2024-04' '2025-04' '2024-08' '2025-08' '2023-12' '2024-12' '2024-02'
#  '2025-02' '2024-01' '2025-01' '2024-07' '2025-07' '2024-06' '2025-06'
#  '2024-03' '2025-03' '2024-05' '2025-05' '2024-11' '2025-11' '2024-10'
#  '2025-10' '2024-09' '2025-09']
# ==================================================
# Kolom day_of_week memiliki kata unique 7
# Datanya: ['Monday' 'Tuesday' 'Wednesday' 'Thursday' 'Friday' 'Saturday' 'Sunday']
# ==================================================
# Kolom order_segment memiliki kata unique 4
# Datanya: ['Small' 'Single' 'Medium' 'Large']
# ==================================================
# Kolom discount_segment memiliki kata unique 6
# Datanya: ['WithOut Discount' '100k-500k' '1-10k' '10k-50k' '50k-100k' '>500k']
# ==================================================

# %%
# ubah jadi category agar mengurangi memori
for col in ['order_status', 'cancellation', 'shipping_option', 'payment_method', 'city', 'province', 'source_file', 'month_period', 'day_of_week', 'order_segment', 'discount_segment']:
    df[col]= df[col].astype('category')

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Pertanyaan Dasar (Univariate Analysis)

# %%
# 1. Berapa total penjualan
print(f"Total penjualan: Rp {df['total_payment'].sum():,}")

# 2. Rata-rata transaksi
print(f"Rata-rata Transaksi: Rp {df['total_payment'].mean():,}")

# 3. Berapa total profit
print(f"Total profit: Rp {df['profit'].sum():,}")
# Out:
# Total penjualan: Rp 1,056,651,631
# Rata-rata Transaksi: Rp 50,683.59703568688
# Total profit: Rp 969,298,706

# %%
# 4. Jumlah pesanan per status

conditions = [
    (df['order_status'] == 'Selesai') & (df['total_returned_qty'] == 0),  # Selesai
    (df['order_status'] == 'Selesai') & (df['total_returned_qty'] > 0),   # Dikembalikan
    (df['order_status'] == 'Batal')                                        # Batal
]
categories = ['Selesai', 'Dikembalikan', 'Batal']

# Hitung jumlah untuk setiap kondisi
for i, (condition, category) in enumerate(zip(conditions, categories)):
    count = df[condition].shape[0]
    percentage = (count / len(df)) * 100
    print(f"{category:15} : {count:>6,} orders ({percentage:>5.1f}%)")

# Total
print("-"*50)
print(f"{'Total':15} : {len(df):>6,} orders (100.0%)")
# Out:
# Selesai         : 17,861 orders ( 85.7%)
# Dikembalikan    :    157 orders (  0.8%)
# Batal           :  2,830 orders ( 13.6%)
# --------------------------------------------------
# Total           : 20,848 orders (100.0%)

# %%
# 5. Cancellation
df.query("cancellation != 'Not Cancelled'")['cancellation'].value_counts()
# Out:
# Dibatalkan oleh Pembeli. Alasan: Lainnya/ berubah pikiran                                                                                             662
# Dibatalkan oleh Pembeli. Alasan: Ubah Pesanan yang Ada                                                                                                558
# Dibatalkan secara otomatis oleh sistem. Alasan: Pesanan belum dibayar                                                                                 447
# Dibatalkan oleh Pembeli. Alasan: Need to change delivery address                                                                                      306
# Dibatalkan secara otomatis oleh sistem. Alasan: Pengiriman gagal                                                                                      255
# Dibatalkan oleh Pembeli. Alasan: Perlu mengubah pesanan                                                                                               113
# Dibatalkan secara otomatis oleh sistem. Alasan: Penjual gagal mengirimkan pesanan tepat waktu                                                         113
# Dibatalkan oleh Pembeli. Alasan: Perlu mengubah alamat pengiriman                                                                                      79
# Dibatalkan secara otomatis oleh sistem. Alasan: Penjual tidak mengatur pengiriman tepat waktu                                                          63
# Dibatalkan oleh Pembeli. Alasan: Lainnya                                                                                                               48
# Dibatalkan oleh Pembeli. Alasan: Perlu mengubah Voucher                                                                                                36
# Dibatalkan oleh Pembeli. Alasan: Proses pembayaran sulit                                                                                               34
# Dibatalkan oleh Pembeli. Alasan: Penjual tidak responsif terhadap pertanyaan Pembeli                                                                   33
# Dibatalkan oleh Pembeli. Alasan: Tidak ingin membeli lagi                                                                                              23
# Dibatalkan secara otomatis oleh sistem. Alasan: Paket hilang di perjalanan. Kompensasi yang memenuhi syarat telah dikreditkan ke Saldo Penjual-mu.     22
# Dibatalkan oleh Pembeli. Alasan: Menemukan yang lebih murah                                                                                            20
# Dibatalkan oleh Penjual. Alasan: Produk habis                                                                                                          14
# Dibatalkan secara otomatis oleh sistem. Alasan: Lainnya                                                                                                 4
# Not Cancelled                                                                                                                                           0
# Name: cancellation, dtype: int64

# %%
# 5. 20 produk dengan jumlah pesanan terbanyak
df.groupby('product_categories')[['total_qty', 'total_returned_qty']].sum().sort_values(by='total_qty', ascending=False).head(20)
# Out:
#                         total_qty  total_returned_qty
# product_categories
# Nampan / Tray                9942                  98
# Mangkok Sambal / Saus        8208                   8
# Celengan                     8206                  12
# Aksesoris Pintu              4523                   8
# Lunch Box / Rantang          3290                  43
# Seal / Baut / Roof           2125                   1
# Baskom / Mangkok Besar       1461                  17
# Keranjang                    1143                  14
# Piring                        895                  11
# Other                         839                  10
# Botol / Gelas / Mug           810                   7
# Tempat Nasi                   637                   3
# Rak / Rak Serbaguna           626                   2
# Aksesoris ID Card             413                   6
# Saringan / Strainer           399                   1
# Peralatan Makan               398                   1
# Aksesoris Mandi               276                   0
# Teko / Jug                    262                   2
# Toples / Sealware             257                   2
# Pisau / Alat Potong           246                   0

# %% [markdown]
# #### Pertanyaan Tren (Time Series Analysis)

# %%
# 1. Tren penjualan per bulan
monthly_sales = df.groupby(['month_period'])['total_payment'].sum().reset_index()
monthly_sales
# Out:
#    month_period  total_payment
# 0       2023-12       23850125
# 1       2024-01       24492481
# 2       2024-02       21141376
# 3       2024-03       30259734
# 4       2024-04       21260662
# 5       2024-05       35530574
# 6       2024-06       32465925
# 7       2024-07       63791545
# 8       2024-08       65939126
# 9       2024-09       71193097
# 10      2024-10       68444255
# 11      2024-11       54907940
# 12      2024-12       56060258
# 13      2025-01       53240632
# 14      2025-02       53088026
# 15      2025-03       43689770
# 16      2025-04       35077659
# 17      2025-05       29139406
# 18      2025-06       30576496
# 19      2025-07       41642561
# 20      2025-08       46950416
# 21      2025-09       47056602
# 22      2025-10       61464654
# 23      2025-11       45388311

# %%
# 2. Hari dengan penjualan tertinggi
df.groupby('day_of_week')['total_payment'].sum().sort_values(ascending= False)
# Out:
# day_of_week
# Monday       175384934
# Wednesday    164376110
# Tuesday      153477715
# Friday       145176700
# Thursday     144426578
# Sunday       141606570
# Saturday     132203024
# Name: total_payment, dtype: int64

# %%
# 3. 10 kota dengan penjualan tertinggi
df.groupby('province')['total_payment'].sum().sort_values(ascending= False)
# Out:
# province
# JAWA BARAT                        276992073
# BANTEN                            177861752
# DKI JAKARTA                       135164841
# JAWA TENGAH                       100114044
# JAWA TIMUR                         95478924
# SUMATERA SELATAN                   40909428
# LAMPUNG                            22028652
# BALI                               21951090
# SUMATERA UTARA                     19783218
# SULAWESI SELATAN                   19680129
# JAMBI                              15651007
# RIAU                               15011507
# NUSA TENGGARA BARAT (NTB)          13047395
# KALIMANTAN BARAT                   12360930
# SUMATERA BARAT                     11217328
# KALIMANTAN SELATAN                 10075885
# KALIMANTAN TIMUR                    9446377
# DI YOGYAKARTA                       9422267
# KALIMANTAN TENGAH                   6949690
# BENGKULU                            6576117
# BANGKA BELITUNG                     6328579
# NANGGROE ACEH DARUSSALAM (NAD)      5936568
# SULAWESI TENGGARA                   4474071
# KEPULAUAN RIAU                      3567630
# SULAWESI UTARA                      3170710
# SULAWESI TENGAH                     3164642
# MALUKU                              2241295
# GORONTALO                           2229815
# NUSA TENGGARA TIMUR (NTT)           1790908
# MALUKU UTARA                        1401836
# KALIMANTAN UTARA                    1173574
# SULAWESI BARAT                      1139349
# PAPUA                                165000
# PAPUA BARAT                          145000
# Name: total_payment, dtype: int64

# %%
# 4. 10 kota dengan penjualan tertinggi
df.groupby('city')['total_payment'].sum().sort_values(ascending= False).head(10)
# Out:
# city
# KAB. TANGERANG            61557031
# KAB. BOGOR                58698901
# KOTA TANGERANG            46541239
# KOTA JAKARTA BARAT        43381103
# KOTA TANGERANG SELATAN    36650441
# KOTA JAKARTA SELATAN      34603898
# KOTA DEPOK                29457272
# KOTA PALEMBANG            26799136
# KAB. BANYUMAS             26397240
# KAB. BEKASI               25187473
# Name: total_payment, dtype: int64

# %% [markdown]
# ### Data Visualization

# %%
# 1. Tren penjualan per bulan (line chart)
plt.figure(figsize=(12,6))

monthly_sales = df.groupby('month_period')['total_payment'].sum()
ax = monthly_sales.plot(kind='line', marker='o')

ax.yaxis.set_major_formatter(lambda x, p: f'{int(x/1e6)}M')

ax.set_xticks(range(len(monthly_sales.index)))  # Set semua posisi
ax.set_xticklabels(monthly_sales.index, rotation=45, ha='right')  # Label semua bulan

plt.title('Tren Penjualan Bulanan', fontsize=16, fontweight='bold')
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Total Penjualan (Rp)', fontsize=12)
plt.tight_layout() 
plt.show()

# %%
# 2. Jumlah Status order (line chart)
plt.figure(figsize=(12,6))

# Buat kondisi untuk 3 kategori
conditions = [
    (df['order_status'] == 'Selesai') & (df['total_returned_qty'] == 0),  # Selesai
    (df['order_status'] == 'Selesai') & (df['total_returned_qty'] > 0),   # Dikembalikan
    (df['order_status'] == 'Batal')                                        # Batal
]

# Nama kategori
categories = ['Selesai', 'Dikembalikan', 'Batal']

# Hitung jumlah untuk setiap kategori
counts = [df[cond].shape[0] for cond in conditions]

# Buat pie chart
colors = sns.color_palette('Set2', n_colors=len(categories))
plt.pie(counts, labels=categories, autopct='%1.1f%%', 
        colors=colors, startangle=90, textprops={'fontsize': 11})

plt.title('Distribusi Status Order', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Grafik penyebab pembatalan pemesanan
cancellation_counts = df[df['cancellation'] != 'Not Cancelled']['cancellation'].value_counts().head(6)

# Buat horizontal bar chart
plt.figure(figsize=(12, 6))
ax = cancellation_counts.plot(kind='barh', color='#E74C3C', width=0.7)

# Tambahkan label nilai di samping bar
for i, (idx, value) in enumerate(cancellation_counts.items()):
    ax.text(value + (cancellation_counts.max() * 0.01), i, f'{value:,}', 
            ha='left', va='center', fontweight='bold', fontsize=11, color='#E74C3C')

# Format sumbu x dengan pemisah ribuan
ax.xaxis.set_major_formatter(lambda x, p: f'{int(x):,}')

plt.title('Top 6 Alasan Pembatalan Order', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Jumlah Order', fontsize=12)
plt.ylabel('Alasan Pembatalan', fontsize=12)

# Layout rapi
plt.tight_layout()
plt.show()

# %%
# Buat grafik 10 province dan kota dengan penjualan terbanyak
sns.set_style('whitegrid')
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

top_provinces = df.groupby('province')['total_payment'].sum().sort_values(ascending=False).head(10)
ax1.bar(range(len(top_provinces)), top_provinces.values, color='#2E86AB')
ax1.yaxis.set_major_formatter(lambda x, p: f'{int(x/1e6)}M')

for i, v in enumerate(top_provinces.values):
    ax1.text(i, v + (top_provinces.max() * 0.01), f'{int(v/1e6)}M', 
            ha='center', va='bottom', fontsize=9, fontweight='bold')

ax1.set_title('Top 10 Provinsi dengan Penjualan Tertinggi', fontsize=14, fontweight='bold')
ax1.set_xlabel('Provinsi', fontsize=11)
ax1.set_ylabel('Total Penjualan (Rp)', fontsize=11)
ax1.set_xticks(range(len(top_provinces.index)))
ax1.set_xticklabels(top_provinces.index, rotation=45, ha='right')
ax1.grid(axis='y', alpha=0.3)


top_cities = df.groupby('city')['total_payment'].sum().sort_values(ascending=False).head(10)
ax2.bar(range(len(top_cities)), top_cities.values, color='#A23B72')

ax2.yaxis.set_major_formatter(lambda x, p: f'{int(x/1e6)}M')

for i, v in enumerate(top_cities.values):
    ax2.text(i, v + (top_cities.max() * 0.01), f'{int(v/1e6)}M', 
            ha='center', va='bottom', fontsize=9, fontweight='bold')

ax2.set_title('Top 10 Kota dengan Penjualan Tertinggi', fontsize=14, fontweight='bold')
ax2.set_xlabel('Kota', fontsize=11)
ax2.set_ylabel('Total Penjualan (Rp)', fontsize=11)
ax2.set_xticks(range(len(top_cities.index)))
ax2.set_xticklabels(top_cities.index, rotation=45, ha='right')
ax2.grid(axis='y', alpha=0.3)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# 3. Rata-rata jumlah penjualan berdasarkan rentang diskon
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))

# Hitung rata-rata qty per rentang diskon
avg_qty_by_discount = df.groupby('discount_segment')['total_qty'].mean()

# Plot
avg_qty_by_discount.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Rata-rata Jumlah Pembelian Berdasarkan Rentang Diskon', fontsize=16, fontweight='bold')
plt.xlabel('Rentang Diskon', fontsize=12)
plt.ylabel('Rata-rata Jumlah Item per Order', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)

# Tambahkan nilai di atas bar
for i, v in enumerate(avg_qty_by_discount):
    plt.text(i, v + 0.1, f'{v:.2f}', ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# 4.Buat grafik jumlah penjualan vs jumlah dikembalikan suatu produk

sns.set_style('whitegrid')
plt.figure(figsize=(12, 6))

# Ambil top 10 kategori berdasarkan total_qty
top_products = df.groupby('product_categories')[['total_qty', 'total_returned_qty']].sum().sort_values('total_qty', ascending=False).head(10)

# Buat stacked bar
ax = top_products[['total_qty', 'total_returned_qty']].plot(
    kind='barh', 
    stacked=True,
    color=['#2E86AB', '#A23B72'],  # Biru untuk terjual, Ungu untuk returned
    figsize=(14, 8),
    width=0.8
)

# Menambahkan label nilai
for i, (idx, row) in enumerate(top_products.iterrows()):
    total = row['total_qty'] + row['total_returned_qty']
    
    # Label untuk total_qty (biru) - tetap di tengah bagian biru
    if row['total_qty'] > 0:
        ax.text(row['total_qty']/2, i, f'{int(row["total_qty"]):,}', 
                ha='center', va='center', color='white', fontweight='bold', fontsize=10)
    
    # Label untuk total_returned_qty dengan format sederhana: "returned dari: total"
    if row['total_returned_qty'] > 0:
        x_pos = row['total_qty'] + row['total_returned_qty'] + (top_products['total_qty'].max() * 0.01)
        ax.text(x_pos, i, f'{int(row["total_returned_qty"]):,} dari: {int(row["total_qty"]):,}', 
                ha='left', va='center', color='#A23B72', fontweight='bold', fontsize=9)

plt.legend(['Terjual', 'Returned'], fontsize=11)
ax.xaxis.set_major_formatter(lambda x, p: f'{int(x):,}')

plt.title('Top 10 Kategori Produk: Perbandingan Terjual vs Returned', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Total Jumlah (Unit)', fontsize=12)
plt.ylabel('Kategori Produk', fontsize=12)

# Layout rapi
plt.tight_layout()
plt.show()

# %%
# 6. Distribusi jumlah pesanan (Pie Chart)
plt.figure(figsize=(12,6))

order_segments = df['order_segment'].value_counts()
colors = sns.color_palette('Set2', n_colors=len(order_segments))
plt.pie(order_segments.values, labels=order_segments.index, autopct='%1.1f%%', 
        colors=colors, startangle=90, textprops={'fontsize': 11})
plt.title('Order Segment', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# tampilkan rata-rata pembelian tiap segmen
avg_qty_per_segment = df.groupby('order_segment')['total_qty'].mean().round(2)
for segment, avg_qty in avg_qty_per_segment.items():
    print(f"Segmen '{segment}' memiliki rata-rata jumlah pembelian: {avg_qty:,.2f} unit")
# Out:
# Segmen 'Large' memiliki rata-rata jumlah pembelian: 21.14 unit
# Segmen 'Medium' memiliki rata-rata jumlah pembelian: 4.74 unit
# Segmen 'Single' memiliki rata-rata jumlah pembelian: 1.00 unit
# Segmen 'Small' memiliki rata-rata jumlah pembelian: 2.23 unit

# %%
# Heatmap untuk melihat hubungan antar variabel (total_qty, total_payment, profit, shipping_cost, total_discount, total_returned_qty)

plt.figure(figsize=(10, 8))

# Pilih kolom numerik yang relevan
numerical_cols = ['total_qty', 'total_payment', 'profit', 'shipping_cost', 
                  'total_discount', 'total_returned_qty']

correlation = df[numerical_cols].corr()

sns.heatmap(correlation, annot=True, fmt='.2f', cmap='coolwarm', 
            square=True, linewidths=0.5)

plt.title('Korelasi Antar Variabel Numerik', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
